# %% [markdown]
# # Set up

# %%
# Import all our favorite packages
import matplotlib       # basic plotting
import matplotlib.pyplot as plt
import numpy as np      # array manipulation and math
import pandas as pd     # working with DataFrames
import rushd as rd      # created by the lab for reproducible data analysis
import scipy as sp      # statistics, etc.
import seaborn as sns   # fancy plotting

# %% [markdown]
# This example uses data from the [ComMAND paper](https://gallowaylab.mit.edu/wp-content/uploads/2025/04/1-s2.0-S2405471225001024-mmc3.pdf), ultimately reproducing the plots from Fig. 2E. This notebook only loads/plots one biological replicate of the data, omitting statistical tests and broader discussion of errorbars.
#
# In this experiment, the base gene, open-loop circuit, and closed-loop ComMAND circuit plasmids (pRC140, pRC142, and pRC143, respectively) were each co-transfected with a marker plasmid (pAIO.039) at several different plasmid amounts. To keep the total amount of DNA the same across conditions, a "filler" plasmid (expressing tagBFP) was also included. In total, there are 17 conditions: 3 circuits x 5 plasmid amounts, plus a condition with only the transfection marker (no circuit) and an untransfected condition. There are three wells (technical replicates) per condition.

# %% [markdown]
# # Loading data
# 0. Set up your computational environment
# 1. Gate single cells in FlowJo
# 2. Specify experimental metadata
# 3. Load data with metadata in Python
#
# See information on Steps 0-2 in the [Loading flow cytometry data](https://gallowaylabmit.github.io/protocols/en/latest/training/data_analysis/flow-data-analysis.html) protocols page.

# %% [markdown]
# ### 2. Specify experimental metadata

# %%
# Visualize the '.yaml' metadata to confirm it's correct
yaml_path = rd.datadir/'attune'/'kasey'/'2024.09.11_exp100.3'/'wells.yaml'
rd.plot.plot_well_metadata(yaml_path)

# %%
''' 
Load plasmid-level metadata

Plasmid features can be defined once (in a '.csv' file) and then 
applied to conditions across many experiments.
'''
metadata_path = rd.rootdir/'inputs'/'plasmid-metadata.csv'
metadata = pd.read_csv(metadata_path)
display(metadata)
# Out:
#     construct promoter                                         name     ts  \
# 0          UT       na                                untransfected     na
# 1          UI       na                                   uninfected     na
# 2       KL012     pMXs                             pMXs-MCP-mCherry   none
# 3       KL019     pMXs           pMXs-MCP-mCherry(miR.FF3)-TS.FF3x1  FF3x1
# 4       KL020     pMXs           pMXs-MCP-mCherry(miR.FF3)-TS.FF3x4  FF3x4
# ..        ...      ...                                          ...    ...
# 244     RC283    TRE3G  TRE3G-FXN-P2A-mRuby2(miRE.FF4)-TS.FF4x1-bGH  FF4x1
# 245     RC284    TRE3G                          TRE3G-EGFP-FMRP-bGH   none
# 246     RC285    TRE3G       TRE3G-EGFP(miRE.FF4)-FMRP-TS.FF6x1-bGH  FF6x1
# 247     RC286    TRE3G       TRE3G-EGFP(miRE.FF4)-FMRP-TS.FF4x1-bGH  FF4x1
# 248    filler       na                                         none     na
#
# ...

# %% [markdown]
# ### 3. Load data with metadata

# %%
'''
Load data from a single plate

Use a rushd function to load only the relevant cytometer channels 
into a single Pandas DataFrame
'''
channel_list = ['mRuby2-A','mGL-A','tagBFP-A']
data_path = rd.datadir/'attune'/'kasey'/'2024.09.11_exp100.3'/'export'
data = rd.flow.load_csv_with_metadata(data_path, yaml_path, columns=channel_list)
display(data)
# Out:
#         construct  plasmid_amount well population  mGL-A  tagBFP-A  mRuby2-A
# 0           RC143           0.500   B7   singlets    -25       -63        60
# 1           RC143           0.500   B7   singlets    -15       -90        99
# 2           RC143           0.500   B7   singlets     60      -133       -18
# 3           RC143           0.500   B7   singlets   1872     18493       -35
# 4           RC143           0.500   B7   singlets   5546     73729       481
# ...           ...             ...  ...        ...    ...       ...       ...
# 5150210     RC142           0.125   D6   singlets    153        13        34
# 5150211     RC142           0.125   D6   singlets     31       637       114
# 5150212     RC142           0.125   D6   singlets     28       105       195
# 5150213     RC142           0.125   D6   singlets      1       -94        -4
# 5150214     RC142           0.125   D6   singlets     41       -29       -11
#
# [5150215 rows x 7 columns]

# %%
'''
ASIDE: Loading multiple plates

For the ComMAND paper, three biological replicates of this experiment
were loaded at once, using a different rushd function for this purpose.
Note that this code takes a while to run.
'''

base_path = rd.datadir/'attune'/'kasey'

# Define metadata for each plate
plates = pd.DataFrame({
    'data_path': [base_path/'2024.07.18_exp100'/'export', 
                  base_path/'2024.09.11_exp100.3'/'export', 
                  base_path/'2024.09.28_exp100.5'/'export',
                 ],
    'yaml_path': [base_path/'2024.09.11_exp100.3'/'wells.yaml']*3,
    'biorep': [1,2,3],
    'exp': ['exp100.1','exp100.3','exp100.5'],
})

data_all_reps = rd.flow.load_groups_with_metadata(plates, columns=channel_list)
display(data_all_reps)

# %%
'''
ASIDE: Save data to local cache

Save data (from relevant channels only) locally to enable offline
and faster loading next time.
'''
output_path = rd.rootdir/'output'/'flow-example_ComMAND'
cache_path = output_path/'data.gzip'
data = pd.DataFrame()

# If the cache file exists, load from cache
if cache_path.is_file(): data = pd.read_parquet(cache_path)

# Otherwise, load from Smithsonian
else: 
    channel_list = ['mRuby2-A','mGL-A','tagBFP-A']
    data = rd.flow.load_csv_with_metadata(data_path, yaml_path, columns=channel_list)
    data.to_parquet(rd.outfile(cache_path)) # save as cache
    
display(data)

# %%
# Merge plasmid-level metadata into data
data = data.merge(metadata, how='left', on='construct')
display(data)
# Out:
#         construct  plasmid_amount well population  mGL-A  tagBFP-A  mRuby2-A  \
# 0           RC143           0.500   B7   singlets    -25       -63        60
# 1           RC143           0.500   B7   singlets    -15       -90        99
# 2           RC143           0.500   B7   singlets     60      -133       -18
# 3           RC143           0.500   B7   singlets   1872     18493       -35
# 4           RC143           0.500   B7   singlets   5546     73729       481
# ...           ...             ...  ...        ...    ...       ...       ...
# 5150210     RC142           0.125   D6   singlets    153        13        34
# 5150211     RC142           0.125   D6   singlets     31       637       114
# 5150212     RC142           0.125   D6   singlets     28       105       195
# 5150213     RC142           0.125   D6   singlets      1       -94        -4
# 5150214     RC142           0.125   D6   singlets     41       -29       -11
#
# ...

# %% [markdown]
# # Exploring data
# 0. Set up plotting defaults
# 1. Draw expression gates for each channel
# 2. Sanity check: Plot single-color controls and untransfected/untransduced cells
# 3. Plot distributions for all conditions in relevant channels
# 4. Calculate summary statistics (e.g., mean) for each condition and plot

# %% [markdown]
# ### 0. Set up plotting defaults

# %%
# Set plotting context for nicer plots
sns.set_style('ticks')
sns.set_context('talk', rc={'font.family': 'sans-serif', 'font.sans-serif':['Helvetica Neue']})

# %%
# Define color palettes manually for constructs
construct_palette = {
    'RC140': 'black',
    'RC142': 'grey',
    'RC143': 'teal',
    'AIO.039': 'darkorange',
    'UT': 'sienna',
}

# Define color palettes for plotting 'ts_kind' (circuit type)
circuit_palette = {
    '–': 'dimgrey', # untransfected
    'na': 'black',  # base gene
    'NT': 'grey',   # OL circuit
    'T': 'teal'     # CL circuit
}

# A modified continuous color palette, removing the hard-to-see yellow end
# To use with plasmid amount, a continuous variable
no_yellow_viridis = matplotlib.colors.ListedColormap(matplotlib.colormaps['viridis'](np.linspace(0,0.82,256)))

# %% [markdown]
# ### 1. Draw expression gates for each channel

# %% [markdown]
# Gates are thresholds that define which channel values represent expressing cells.
# These can be defined as some percentile of the untransfected condition, e.g., the
# 99.9th percentile such that only 0.1% of untransfected cells are considered expressing.
# Alternatively, gates can be drawn manually.

# %%
# Define the expression threshold (gate) for the transfection marker
transfection_gate = data.loc[data['construct']=='UT', 'mGL-A'].quantile(0.999)
display(transfection_gate)
# Out:
# np.float64(242.0)

# %%
# Generate gates for each channel all at once
gates = data.loc[data['construct']=='UT', channel_list].apply(lambda x: x.quantile(0.999))
display(gates.to_dict())
# Out:
# {'mRuby2-A': 207.0, 'mGL-A': 242.0, 'tagBFP-A': 268.0}

# %% [markdown]
# ### 2. Sanity check: Plot single-color controls and untransfected cells

# %% [markdown]
# The first thing you'll likely want to do is visualize distributions of expression across relevant channels for various conditions. The easiest way to plot multiple conditions at once is by using Seaborn's FacetGrid and related functions: https://seaborn.pydata.org/tutorial/axis_grids.html. With these functions, you shouldn't have to define each axis yourself!
#
# Seaborn plotting functions come in several types:
#
# 1. **Functions that generate a single axis** (return a matplotlib `Axes` object). You can facet the data on up to two columns (e.g., one category on the x-axis and the other as the color). This includes `scatterplot`, `kdeplot`, etc.
#
# 2. **Functions that generate a grid of axes** (return a Seaborn `FacetGrid` object). You can facet the data on up to four columns (e.g., x-axis, color, row in the grid, column in the grid). These functions typically have several different plot type options, which you can specify with the `kind` argument. For instance, `catplot` includes 'strip', 'bar', 'violin' and other plot types with one categorical axis, while `displot` includes 'kde' and 'hist' plots to show 1D or 2D distributions.
#
# You probably want to begin by using `kdeplot` to plot 1D or 2D distributions: https://seaborn.pydata.org/generated/seaborn.kdeplot.html. Note that 2D kdeplots may take several minutes to generate.

# %%
# Subset data to exclude non-positive values for plotting on log axes
data_log_friendly = data[(data['tagBFP-A']>0) & (data['mGL-A']>0) & (data['mRuby2-A']>0)].copy()

# %%
# Plot untransfected condition with gates as lines
plot_df = data_log_friendly[data_log_friendly['construct']=='UT']
x = 'mGL-A'
y = 'mRuby2-A'
f = sns.kdeplot(data=plot_df, x=x, y=y, hue='construct', palette=construct_palette,
                log_scale=True, common_norm=False, legend=False)
f.axvline(gates[x], color='lightgrey', ls=':', zorder=0) # for fun, change plot style
f.axhline(gates[y], color='black')

# %%
# Plot both the untransfected and marker-only conditions as a sanity check
f, axes = plt.subplots(1,2, figsize=(10,4), sharex=True, sharey=True,)

x = 'mGL-A'
y = 'mRuby2-A'

ax = axes[0]
plot_df = data_log_friendly[data_log_friendly['construct']=='UT']
sns.kdeplot(data=plot_df, x=x, y=y, hue='construct', palette=construct_palette,
            log_scale=True, common_norm=False, legend=False, ax=ax)
ax.axvline(gates[x], color='black', zorder=0)
ax.axhline(gates[y], color='black', zorder=0)

ax = axes[1]
plot_df = data_log_friendly[data_log_friendly['construct']=='AIO.039']
sns.kdeplot(data=plot_df, x=x, y=y, hue='construct', palette=construct_palette,
            log_scale=True, common_norm=False, legend=False, ax=ax)
ax.axvline(gates[x], color='black', zorder=0)
ax.axhline(gates[y], color='black', zorder=0)

# %% [markdown]
# ### 3. Plot distributions for all conditions in relevant channels

# %%
# Plot 1D distributions for circuit conditions
plot_df = data_log_friendly[data_log_friendly['construct'].isin(['RC140','RC142','RC143'])]
x = 'mGL-A'
g = sns.displot(data=plot_df, x=x, col='construct',
                hue='plasmid_amount', palette=no_yellow_viridis, kind='kde', hue_norm=matplotlib.colors.LogNorm(),
                log_scale=True, common_norm=False)

for construct, ax in g.axes_dict.items():
    ax.axvline(gates[x], color='black', zorder=0)

# %%
plot_df = data_log_friendly[data_log_friendly['construct'].isin(['RC140','RC142','RC143'])]
x = 'mRuby2-A'
g = sns.displot(data=plot_df, x=x, col='construct',
                hue='plasmid_amount', palette=no_yellow_viridis, kind='kde', hue_norm=matplotlib.colors.LogNorm(),
                log_scale=True, common_norm=False)

for construct, ax in g.axes_dict.items():
    ax.axvline(gates[x], color='black', zorder=0)

# %%
# Plot 2D distributions for circuit conditions
plot_df = data_log_friendly[data_log_friendly['construct'].isin(['RC140','RC142','RC143'])]
plot_df_sample = plot_df.groupby(['construct','plasmid_amount']).sample(1000) # downsample for faster plots
x = 'mGL-A'
y = 'mRuby2-A'
g = sns.displot(data=plot_df_sample, x=x, y=y, row='construct', col='plasmid_amount',
                hue='plasmid_amount', palette=no_yellow_viridis, kind='kde', hue_norm=matplotlib.colors.LogNorm(),
                facet_kws={'margin_titles': True}, log_scale=True, common_norm=False)

for (amount, construct), ax in g.axes_dict.items():
    ax.axvline(gates[x], color='black', zorder=0)
    ax.axhline(gates[y], color='black', zorder=0)

# %%
''' 
Subset transfected cells

Define transfected cells as those expressing the transfection marker (mGL),
and use this subset for all subsequent analyses.
'''
data_transfected = data[(data['construct']!='UT') & (data['mGL-A']>gates['mGL-A'])].copy()
data_transfected_log_friendly = data_transfected[(data_transfected['mRuby2-A']>0) & (data_transfected['tagBFP-A']>0)]

# %%
# Visualize transfected subset
plot_df = data_transfected_log_friendly[data_transfected_log_friendly['construct'].isin(['RC140','RC142','RC143'])]
plot_df_sample = plot_df.groupby(['construct','plasmid_amount']).sample(1000)
x = 'mGL-A'
y = 'mRuby2-A'
g = sns.displot(data=plot_df_sample, x=x, y=y, row='construct', col='plasmid_amount',
                hue='plasmid_amount', palette=no_yellow_viridis, kind='kde', hue_norm=matplotlib.colors.LogNorm(),
                facet_kws={'margin_titles': True}, log_scale=True, common_norm=False)

for (amount, construct), ax in g.axes_dict.items():
    ax.axvline(gates[x], color='black', zorder=0)
    ax.axhline(gates[y], color='black', zorder=0)

# %% [markdown]
# ### 4. Calculate summary statistics (e.g., mean) for each condition

# %% [markdown]
# Now that you've explored the distributions for each condition, you probably want to quantify trends. Calculating summary statistics (mean, standard deviation, etc.) is straightforward and quick with Pandas functions using the groupby-apply paradigm.

# %%
stat_list = [sp.stats.gmean, np.std,]
by = ['construct','plasmid_amount']
stats = data_transfected_log_friendly.groupby(by)[channel_list].agg(stat_list).reset_index().dropna()
stats.columns = ['_'.join(c).rstrip('_') for c in stats.columns.to_flat_index()] # rename columns
stats = stats.merge(metadata, how='left', on='construct') # add plasmid metadata
display(stats)
# Out:
#    construct  plasmid_amount  mRuby2-A_gmean  mRuby2-A_std  mGL-A_gmean  \
# 0    AIO.039          1.0000       36.785291     40.322416   665.566940
# 1      RC140          0.0625      151.261012    682.359625   677.291628
# 2      RC140          0.1250      349.943893   1619.132749   702.700542
# 3      RC140          0.2500      726.419261   2700.621002   702.254362
# 4      RC140          0.5000     1597.942893   4487.032383   713.757535
# 5      RC140          1.0000     3345.811285   7862.253525   677.733369
# 6      RC142          0.0625      193.081876    979.229785   698.190132
# 7      RC142          0.1250      436.546818   2338.101851   704.750912
# 8      RC142          0.2500      987.212202   4386.640518   724.218024
# 9      RC142          0.5000     2938.389476   8366.828883   852.008160
# 10     RC142          1.0000     7374.643902  14389.302950   909.875154
# 11     RC143          0.0625       49.671910     60.368408   727.004970
# ...

# %%
plot_df = stats[stats['construct']!='AIO.039']
x = 'plasmid_amount'
y = 'mRuby2-A_gmean'
f = sns.scatterplot(data=plot_df, x=x, y=y, hue='ts_kind', palette=circuit_palette, marker='o')
f.set(yscale='log')
# Out:
# [None]

# %% [markdown]
# # Summarizing analyses
# 1. Calculate additional metrics (e.g., slope, fold change)
# 2. Perform statistical tests on replicates
# 3. Choose important plots and polish for clarity

# %% [markdown]
# ### 1. Calculate additional metrics (e.g., slope, fold change)

# %%
''' 
Bin transfected cells into quantiles

Bin the data such that there are the same number of cells in each bin.
Use 'qcut' for this. (To generate equal-width bins, use 'cut'.)
'''
num_bins = 15
data_transfected['mGL-A_quantiles'] = data_transfected.groupby(['construct','plasmid_amount'])['mGL-A'].transform(lambda x: pd.qcut(x, q=num_bins, duplicates='drop'))
quantiles = data_transfected.groupby(['construct','plasmid_amount','mGL-A_quantiles'])['mGL-A'].median().rename('mGL-A_quantiles_median').reset_index()
data_transfected = data_transfected.merge(quantiles, how='left', on=['construct','plasmid_amount','mGL-A_quantiles'])
data_transfected_log_friendly = data_transfected[(data_transfected['mRuby2-A']>0) & (data_transfected['tagBFP-A']>0)] # update this
display(data_transfected)
# Out:
#        construct  plasmid_amount well population  mGL-A  tagBFP-A  mRuby2-A  \
# 0          RC143           0.500   B7   singlets   1872     18493       -35
# 1          RC143           0.500   B7   singlets   5546     73729       481
# 2          RC143           0.500   B7   singlets    706      8990        70
# 3          RC143           0.500   B7   singlets    832     13245        26
# 4          RC143           0.500   B7   singlets    387     12345       267
# ...          ...             ...  ...        ...    ...       ...       ...
# 935059     RC142           0.125   D6   singlets    315      1147        79
# 935060     RC142           0.125   D6   singlets    503      9453       -70
# 935061     RC142           0.125   D6   singlets    413      5762       381
# 935062     RC142           0.125   D6   singlets    328     22332      1196
# 935063     RC142           0.125   D6   singlets    776      7575       194
#
# ...

# %%
# Plot the bins, using auto-summarization ('estimator'/'errorbar' params) with 'relplot'
plot_df = data_transfected_log_friendly[data_transfected_log_friendly['construct']!='AIO.039']
x = 'mGL-A_quantiles_median'
y = 'mRuby2-A'

g = sns.relplot(data=plot_df, x=x, y=y, hue='plasmid_amount', palette=no_yellow_viridis, hue_norm=matplotlib.colors.LogNorm(),
                col='ts_kind', facet_kws={'margin_titles': True},
                kind='line', marker='o', estimator=sp.stats.gmean, 
                errorbar=lambda x: (sp.stats.gmean(x) / sp.stats.gstd(x), sp.stats.gmean(x) * sp.stats.gstd(x)),
                col_order=['na','NT','T'])
g.set(xscale='log', yscale='log')

# %% [markdown]
# The left and right plots above are the left and middle plots of Fig. 2E in the paper.

# %%
# Compute summary statistics for each bin
stat_list = [sp.stats.gmean, np.std,]
stats_binned = data_transfected_log_friendly.groupby(['construct','plasmid_amount','mGL-A_quantiles_median'])[channel_list].agg(stat_list).reset_index().dropna()
stats_binned.columns = ['_'.join(c).rstrip('_') for c in stats_binned.columns.to_flat_index()]
display(stats_binned)
# Out:
#     construct  plasmid_amount  mGL-A_quantiles_median  mRuby2-A_gmean  \
# 0     AIO.039             1.0                   253.0       36.984061
# 1     AIO.039             1.0                   277.0       35.498757
# 2     AIO.039             1.0                   305.0       36.824172
# 3     AIO.039             1.0                   339.0       38.991146
# 4     AIO.039             1.0                   380.0       34.628762
# ..        ...             ...                     ...             ...
# 235     RC143             1.0                  2065.0      400.197570
# 236     RC143             1.0                  2593.0      473.479885
# 237     RC143             1.0                  3376.0      568.522664
# 238     RC143             1.0                  4655.0      715.273287
# 239     RC143             1.0                  8155.5     1124.644198
#
#      mRuby2-A_std  mGL-A_gmean    mGL-A_std  tagBFP-A_gmean  tagBFP-A_std
# ...

# %%
# Log-transform the data, since points are linear in logspace
stats_binned['mGL-A_quantiles_median_log'] = stats_binned['mGL-A_quantiles_median'].apply(np.log10)
stats_binned['mRuby2-A_gmean_log'] = stats_binned['mRuby2-A_gmean'].apply(np.log10)

# %%
'''
Compute slope for each condition

Slope here is the slope of the line fitted to the log-transformed, binned marker-vs-circuit
points. Since there isn't a function that is directly compatible with DataFrames, define 
a custom function to apply to groups.
'''
def get_slope(df, x, y):
    slope, intercept, r_value, p_value, stderr = sp.stats.linregress(df[x], df[y])
    result = pd.DataFrame({
        'slope': slope, 
        'intercept': intercept,
        'r_value': r_value,
        'p_value': p_value,
        'stderr': stderr,
    }, index=[0])
    return result

slopes = stats_binned.groupby(['construct','plasmid_amount'])[stats_binned.columns].apply(get_slope, 'mGL-A_quantiles_median_log', 'mRuby2-A_gmean_log').reset_index()
display(slopes)
# Out:
#    construct  plasmid_amount  level_2     slope  intercept   r_value  \
# 0    AIO.039          1.0000        0 -0.001933   1.570924 -0.027403
# 1      RC140          0.0625        0  0.907794  -0.385212  0.992815
# 2      RC140          0.1250        0  1.074432  -0.510971  0.999026
# 3      RC140          0.2500        0  1.089784  -0.237286  0.999537
# 4      RC140          0.5000        0  1.089273   0.098023  0.998506
# 5      RC140          1.0000        0  1.112149   0.378427  0.999113
# 6      RC142          0.0625        0  0.939543  -0.381004  0.992686
# 7      RC142          0.1250        0  1.064240  -0.386838  0.998308
# 8      RC142          0.2500        0  1.066172  -0.051507  0.999695
# 9      RC142          0.5000        0  1.063998   0.352433  0.997183
# 10     RC142          1.0000        0  1.084136   0.661544  0.996126
# 11     RC143          0.0625        0  0.230529   1.037305  0.918816
# 12     RC143          0.1250        0  0.389399   0.674402  0.951386
# ...

# %%
# Add slope values to the main stats DataFrame
stats = stats.merge(slopes, how='left', on=by).drop(columns=['level_2'])
display(stats)
# Out:
#    construct  plasmid_amount  mRuby2-A_gmean  mRuby2-A_std  mGL-A_gmean  \
# 0    AIO.039          1.0000       36.785291     40.322416   665.566940
# 1      RC140          0.0625      151.261012    682.359625   677.291628
# 2      RC140          0.1250      349.943893   1619.132749   702.700542
# 3      RC140          0.2500      726.419261   2700.621002   702.254362
# 4      RC140          0.5000     1597.942893   4487.032383   713.757535
# 5      RC140          1.0000     3345.811285   7862.253525   677.733369
# 6      RC142          0.0625      193.081876    979.229785   698.190132
# 7      RC142          0.1250      436.546818   2338.101851   704.750912
# 8      RC142          0.2500      987.212202   4386.640518   724.218024
# 9      RC142          0.5000     2938.389476   8366.828883   852.008160
# 10     RC142          1.0000     7374.643902  14389.302950   909.875154
# 11     RC143          0.0625       49.671910     60.368408   727.004970
# ...

# %%
# Plot slope as a function of plasmid amount
plot_df = stats[stats['construct']!='AIO.039']
x = 'plasmid_amount'
y = 'slope'
f = sns.lineplot(data=plot_df, x=x, y=y, hue='ts_kind', palette=circuit_palette, marker='o')

# %% [markdown]
# This is the right plot in Fig. 2E of the paper.

# %% [markdown]
# ### 2. Perform statistical tests on replicates

# %% [markdown]
# Normally, statistical tests would be performed on *biological* replicates. Just for illustrative purposes, statistical tests are shown below for the technical replicates in this experiment. This requires recomputing summary stats, grouping by technical replicate (well).

# %%
# Compute summary stats on wells
stat_list = [sp.stats.gmean, np.std,]
by = ['construct','plasmid_amount','well']
stats_by_well = data_transfected_log_friendly.groupby(by)[channel_list].agg(stat_list).reset_index().dropna()
stats_by_well.columns = ['_'.join(c).rstrip('_') for c in stats_by_well.columns.to_flat_index()] # rename columns
stats_by_well = stats_by_well.merge(metadata, how='left', on='construct') # add plasmid metadata
display(stats_by_well)
# Out:
#    construct  plasmid_amount well  mRuby2-A_gmean  mRuby2-A_std  mGL-A_gmean  \
# 0    AIO.039          1.0000  A10       37.458799     40.495687   662.639649
# 1    AIO.039          1.0000  A11       36.676442     40.650932   670.492526
# 2    AIO.039          1.0000  A12       36.139059     39.552091   661.377395
# 3      RC140          0.0625   E1      167.680518    666.500889   684.415794
# 4      RC140          0.0625   E2      152.201182    758.901139   686.211238
# 5      RC140          0.0625   E3      131.123409    626.546278   660.100187
# 6      RC140          0.1250   D1      366.499800   1647.944736   703.961525
# 7      RC140          0.1250   D2      341.369315   1559.718191   701.385802
# 8      RC140          0.1250   D3      341.261944   1638.079606   702.542294
# 9      RC140          0.2500   C1      831.801505   2819.980098   736.183809
# 10     RC140          0.2500   C2      631.453776   2585.746259   673.844990
# ...

# %%
# Also compute slopes
stat_list = [sp.stats.gmean, np.std,]
stats_by_well_binned = data_transfected_log_friendly.groupby(['construct','plasmid_amount','well','mGL-A_quantiles_median'])[channel_list].agg(stat_list).reset_index().dropna()
stats_by_well_binned.columns = ['_'.join(c).rstrip('_') for c in stats_by_well_binned.columns.to_flat_index()]

stats_by_well_binned['mGL-A_quantiles_median_log'] = stats_by_well_binned['mGL-A_quantiles_median'].apply(np.log10)
stats_by_well_binned['mRuby2-A_gmean_log'] = stats_by_well_binned['mRuby2-A_gmean'].apply(np.log10)

slopes_by_well = stats_by_well_binned.groupby(['construct','plasmid_amount','well'])[stats_by_well_binned.columns].apply(get_slope, 'mGL-A_quantiles_median_log', 'mRuby2-A_gmean_log').reset_index()
stats_by_well = stats_by_well.merge(slopes_by_well, how='left', on=['construct','plasmid_amount','well'])
display(stats_by_well)
# Out:
#    construct  plasmid_amount well  mRuby2-A_gmean  mRuby2-A_std  mGL-A_gmean  \
# 0    AIO.039          1.0000  A10       37.458799     40.495687   662.639649
# 1    AIO.039          1.0000  A11       36.676442     40.650932   670.492526
# 2    AIO.039          1.0000  A12       36.139059     39.552091   661.377395
# 3      RC140          0.0625   E1      167.680518    666.500889   684.415794
# 4      RC140          0.0625   E2      152.201182    758.901139   686.211238
# 5      RC140          0.0625   E3      131.123409    626.546278   660.100187
# 6      RC140          0.1250   D1      366.499800   1647.944736   703.961525
# 7      RC140          0.1250   D2      341.369315   1559.718191   701.385802
# 8      RC140          0.1250   D3      341.261944   1638.079606   702.542294
# 9      RC140          0.2500   C1      831.801505   2819.980098   736.183809
# 10     RC140          0.2500   C2      631.453776   2585.746259   673.844990
# ...

# %%
# Plot slopes for technical reps
plot_df = stats_by_well[stats_by_well['construct']!='AIO.039']
x = 'plasmid_amount'
y = 'slope'
f = sns.lineplot(data=plot_df, x=x, y=y, hue='ts_kind', palette=circuit_palette, marker='o')

# %% [markdown]
# The shaded regions above represent standard error on the technical replicates, which are quite close together as expected.

# %%
''' 
Perform statistical tests

Compare slopes for the base gene and closed-loop ComMAND circuit at each plasmid amount.
'''
def perform_t_tests(df, test_col, val_col, vals):
    data1 = df.loc[df[val_col]==vals[0], test_col]
    data2 = df.loc[df[val_col]==vals[1], test_col]
    return sp.stats.ttest_ind(data1, data2).pvalue

result = stats_by_well.groupby(['plasmid_amount'])[stats_by_well.columns].apply(perform_t_tests, 'slope', 'construct', ('RC140','RC143')).reset_index().rename(columns={0: 'ttest_pvalue'})
display(result)
# Out:
#    plasmid_amount  ttest_pvalue
# 0          0.0625  6.408766e-07
# 1          0.1250  5.806711e-09
# 2          0.2500  3.166767e-06
# 3          0.5000  7.420385e-07
# 4          1.0000  2.487492e-06

# %%
# Convert p-values to stars for plotting
star_convert = list(reversed([(1.0, 'n.s.'), (0.05, '*'), (0.01, '**'), (0.001, '***'), (0.0001, '****')]))
pval_to_stars = lambda x: next(val[1] for val in star_convert if val[0] > x)
result['ttest_star'] = result['ttest_pvalue'].apply(pval_to_stars)
display(result)
# Out:
#    plasmid_amount  ttest_pvalue ttest_star
# 0          0.0625  6.408766e-07       ****
# 1          0.1250  5.806711e-09       ****
# 2          0.2500  3.166767e-06       ****
# 3          0.5000  7.420385e-07       ****
# 4          1.0000  2.487492e-06       ****

# %%
# Plot with stars
plot_df = stats_by_well[stats_by_well['construct']!='AIO.039']
x = 'plasmid_amount'
y = 'slope'
f = sns.lineplot(data=plot_df, x=x, y=y, hue='ts_kind', palette=circuit_palette, marker='o')

yloc = 1.15
pad = 0.03
for r in result.itertuples(index=False):
    t = f.text(r.plasmid_amount, yloc - pad * (r.ttest_star.startswith('*')), r.ttest_star, 
               ha='center', va='center')

# %% [markdown]
# ### 3. Choose important plots and polish for clarity

# %% [markdown]
# Not all the plots generated during the exploration phase will be relevant to present elsewhere. Choose the most interesting and relevant plots, then polish them to make the message most clear.

# %%
''' 
Reproduce ComMAND Fig. 2E

This code is very similar to that used to generate the figure for the paper, 
missing only the biological replicates needed for the errorbar shading in the
right plot. This plot is a bit small/cramped for a slide and has over-the-top 
formatting customization; however, it gives a sense of how plotting parameters 
can be tweaked.
'''

f, axes = plt.subplots(1,3, gridspec_kw=dict(wspace=0.8), figsize=(10,2))

main_markers = {'RC140': 'X', 'RC142': 'o', 'RC143': 'o'}
greys = matplotlib.colors.ListedColormap(matplotlib.colormaps['Greys'](np.linspace(0.4,1,256)))
teals = sns.light_palette('teal', 4)[1:] + sns.dark_palette('teal', 4, reverse=True)[1:-1]
amounts = sorted([float(d) for d in data_transfected['plasmid_amount'].unique() if not np.isnan(d)])
teals_palette = dict(zip(amounts, teals))
line_kwargs = {'legend': False, 'dashes': False, 'markersize': 7, 'markeredgecolor': 'white', 'markeredgewidth': 0.5}


# Line plot, base gene
ax = axes[0]
plot_df = data_transfected_log_friendly[data_transfected_log_friendly['group']=='base']
sns.lineplot(data=plot_df, x='mGL-A_quantiles_median', y='mRuby2-A', hue='plasmid_amount', palette=greys, ax=ax,
             style='construct', markers=main_markers, hue_norm=matplotlib.colors.LogNorm(), **line_kwargs)
ax.set(xscale='log', yscale='log', xlabel='marker', ylabel='output', title='base gene',)
marker_baseline = stats.loc[(stats['construct']=='AIO.039'), 'mRuby2-A_gmean'].mean()
ax.axhline(marker_baseline, color='black', ls=':', zorder=0)
ax.yaxis.set_tick_params(which='minor', left=False)

# Line plot, closed-loop ComMAND circuit
ax = axes[1]
plot_df = data_transfected_log_friendly[data_transfected_log_friendly['ts_kind']=='T']
sns.lineplot(data=plot_df, x='mGL-A_quantiles_median', y='mRuby2-A', hue='plasmid_amount', palette=teals_palette, ax=ax,
             style='construct', markers=main_markers, hue_norm=matplotlib.colors.LogNorm(), **line_kwargs)
ax.set(xscale='log', yscale='log', xlabel='marker', ylabel='output', ylim=(2e1,4e3))
ax.set_title(label='CL circuit', color='teal')
ax.axhline(marker_baseline, color='black', ls=':', zorder=0)
ax.minorticks_off()

# Stats slope vs plasmid amount
ax = axes[2]
plot_df = stats[stats['construct']!='AIO.039']
sns.lineplot(data=plot_df, x='plasmid_amount', y='slope', hue='construct', palette=construct_palette, ax=ax,
             style='construct', markers=main_markers, **line_kwargs)
ax.set(ylim=(0,1.2), yticks=(0,0.2,0.4,0.6,0.8,1),
       xlabel='rel. plasmid amt.', xticks=[0.5**i for i in range(5)]+[0], xticklabels=['1.0','0.5','','','',''], xlim=(0,1.1))
sns.despine()

f.savefig(rd.outfile(output_path/'ComMAND-fig-2E-reproduced.png'), bbox_inches='tight')
